# %%
# !pip install librosa
# Out:
# ...
#      -------------------------------------- 253.0/253.0 kB 2.2 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 1.0/1.0 MB 2.9 MB/s eta 0:00:00
# ...
#      -------------------------------------- 377.0/377.0 kB 2.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#      -------------------------------------- 184.0/184.0 kB 2.2 MB/s eta 0:00:00
# ...
#   Created wheel for audioread: filename=audioread-3.0.0-py3-none-any.whl size=23736 sha256=e2520a0616fc179332ff05d7c7ddc54afc940b47952a02b378670ba70db8b1c6
#   Stored in directory: c:\users\dell\appdata\local\pip\cache\wheels\3d\e0\4b\51b8aa4a0e2b6361c14943f7a7c2c7adb7b9cd419e0a1b720d
# Successfully built audioread
# ...

# %%
# !pip install --upgrade librosa

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import IPython.display as ipd
import librosa
import librosa.display

# %%
filename1='UrbanSound8k/Gunshot.wav'

# %%
#Gun sound
plt.figure(figsize=(14,5))
data,sample_rate=librosa.load(filename1)
librosa.display.waveshow(data,sr=sample_rate)
ipd.Audio(filename)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
sample_rate
# Out:
# 22050

# %%
from scipy.io import wavfile as wav
wave_sample_rate, wave_audio=wav.read(filename1)
wave_sample_rate
# Out:
# 44100

# %%
wave_audio
# Out:
# array([[  6,  12],
#        [  5,   9],
#        [  5,  10],
#        ...,
#        [ 12, -21],
#        [ 11, -26],
#        [ 13, -34]], dtype=int16)

# %%
filename2='UrbanSound8K/audio/fold3/98681-9-0-6.wav'
plt.figure(figsize=(14,5))
data,sample_rate=librosa.load(filename2)
librosa.display.waveshow(data,sr=sample_rate)
ipd.Audio(filename2)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from scipy.io import wavfile as wav
wave_sample_rate, wave_audio=wav.read(filename2)

# %%
wave_sample_rate
# Out:
# 44100

# %%
wave_audio
# Out:
# array([[  6,  12],
#        [  5,   9],
#        [  5,  10],
#        ...,
#        [ 12, -21],
#        [ 11, -26],
#        [ 13, -34]], dtype=int16)

# %%
data
# Out:
# array([-0.00976551, -0.0099922 , -0.01322963, ..., -0.01712941,
#        -0.00509277,  0.00135862], dtype=float32)

# %%
##importing dataset

metadata=pd.read_csv('UrbanSound8K/metadata/UrbanSound8K.csv')

# %%
metadata.head()
# Out:
#       slice_file_name    fsID  start        end  salience  fold  classID  \
# 0    100032-3-0-0.wav  100032    0.0   0.317551         1     5        3
# 1  100263-2-0-117.wav  100263   58.5  62.500000         1     5        2
# 2  100263-2-0-121.wav  100263   60.5  64.500000         1     5        2
# 3  100263-2-0-126.wav  100263   63.0  67.000000         1     5        2
# 4  100263-2-0-137.wav  100263   68.5  72.500000         1     5        2
#
#               class
# 0          dog_bark
# 1  children_playing
# 2  children_playing
# 3  children_playing
# 4  children_playing

# %%
metadata.shape
# Out:
# (8732, 8)

# %%
metadata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8732 entries, 0 to 8731
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   slice_file_name  8732 non-null   object
#  1   fsID             8732 non-null   int64
#  2   start            8732 non-null   float64
#  3   end              8732 non-null   float64
#  4   salience         8732 non-null   int64
#  5   fold             8732 non-null   int64
#  6   classID          8732 non-null   int64
#  7   class            8732 non-null   object
# dtypes: float64(2), int64(4), object(2)
# memory usage: 545.9+ KB

# %%
metadata['class'].value_counts()
# Out:
# dog_bark            1000
# children_playing    1000
# air_conditioner     1000
# street_music        1000
# engine_idling       1000
# jackhammer          1000
# drilling            1000
# siren                929
# car_horn             429
# gun_shot             374
# Name: class, dtype: int64
